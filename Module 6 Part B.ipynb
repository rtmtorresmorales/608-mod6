# %%
# Module 6 Assignment Ramon Torres SEPT 23 2022

# %%
import sqlite3

# %%
connection = sqlite3.connect('books.db')

# %%
import pandas as pd

# %%
pd.options.display.max_columns = 10

# %%
pd.read_sql('SELECT * FROM authors', connection,
            index_col=['id'])
# Out:
#         first    last
# id
# 1        Paul  Deitel
# 2      Harvey  Deitel
# 3       Abbey  Deitel
# 4         Dan   Quirk
# 5   Alexander    Wald

# %%
pd.read_sql('SELECT * FROM author_ISBN', connection,
            index_col=['id'])
# Out:
#           isbn
# id
# 1   0134289366
# 2   0134289366
# 5   0134289366
# 1   0135404673
# 2   0135404673
# 1   0132151006
# 2   0132151006
# 3   0132151006
# 1   0134743350
# 2   0134743350
# 1   0133976890
# 2   0133976890
# 1   0133406954
# 2   0133406954
# 3   0133406954
# 1   0134601548
# 2   0134601548
# 1   0136151574
# 2   0136151574
# 4   0136151574
# 1   0134448235
# 2   0134448235
# 1   0134444302
# 2   0134444302

# %%
pd.read_sql("""SELECT title, edition, copyright
           FROM titles
           WHERE copyright > '2016'""", connection)
# Out:
#                            title  edition copyright
# 0  Intro to Python for CS and DS        1      2020
# 1            Java How to Program       11      2018
# 2       Visual C# How to Program        6      2017
# 3             C++ How to Program       10      2017
# 4         Android How to Program        3      2017

# %%
pd.read_sql('SELECT title FROM titles ORDER BY title ASC', connection)
# Out:
#                               title
# 0         Android 6 for Programmers
# 1            Android How to Program
# 2                  C How to Program
# 3                C++ How to Program
# 4     Internet & WWW How to Program
# 5     Intro to Python for CS and DS
# 6               Java How to Program
# 7  Visual Basic 2012 How to Program
# 8          Visual C# How to Program
# 9         Visual C++ How to Program

# %%
pd.read_sql('SELECT title FROM titles ORDER BY title DESC', connection)
# Out:
#                               title
# 0         Visual C++ How to Program
# 1          Visual C# How to Program
# 2  Visual Basic 2012 How to Program
# 3               Java How to Program
# 4     Intro to Python for CS and DS
# 5     Internet & WWW How to Program
# 6                C++ How to Program
# 7                  C How to Program
# 8            Android How to Program
# 9         Android 6 for Programmers

# %%
pd.read_sql('SELECT title FROM titles ORDER BY title', connection)
# Out:
#                               title
# 0         Android 6 for Programmers
# 1            Android How to Program
# 2                  C How to Program
# 3                C++ How to Program
# 4     Internet & WWW How to Program
# 5     Intro to Python for CS and DS
# 6               Java How to Program
# 7  Visual Basic 2012 How to Program
# 8          Visual C# How to Program
# 9         Visual C++ How to Program

# %%
pd.read_sql("""SELECT title, edition, copyright
           FROM titles
           ORDER BY title """ , connection)
# Out:
#                               title  edition copyright
# 0         Android 6 for Programmers        3      2016
# 1            Android How to Program        3      2017
# 2                  C How to Program        8      2016
# 3                C++ How to Program       10      2017
# 4     Internet & WWW How to Program        5      2012
# 5     Intro to Python for CS and DS        1      2020
# 6               Java How to Program       11      2018
# 7  Visual Basic 2012 How to Program        6      2014
# 8          Visual C# How to Program        6      2017
# 9         Visual C++ How to Program        2      2008

# %%
pd.read_sql("""SELECT title, edition, copyright
           FROM titles
           ORDER BY edition """ , connection)
# Out:
#                               title  edition copyright
# 0     Intro to Python for CS and DS        1      2020
# 1         Visual C++ How to Program        2      2008
# 2            Android How to Program        3      2017
# 3         Android 6 for Programmers        3      2016
# 4     Internet & WWW How to Program        5      2012
# 5  Visual Basic 2012 How to Program        6      2014
# 6          Visual C# How to Program        6      2017
# 7                  C How to Program        8      2016
# 8                C++ How to Program       10      2017
# 9               Java How to Program       11      2018

# %%
pd.read_sql("""SELECT title, edition, copyright
           FROM titles
           ORDER BY copyright """ , connection)
# Out:
#                               title  edition copyright
# 0         Visual C++ How to Program        2      2008
# 1     Internet & WWW How to Program        5      2012
# 2  Visual Basic 2012 How to Program        6      2014
# 3                  C How to Program        8      2016
# 4         Android 6 for Programmers        3      2016
# 5          Visual C# How to Program        6      2017
# 6                C++ How to Program       10      2017
# 7            Android How to Program        3      2017
# 8               Java How to Program       11      2018
# 9     Intro to Python for CS and DS        1      2020

# %%
pd.read_sql("""SELECT first, last
           FROM authors
           ORDER BY last """ , connection)
# Out:
#        first    last
# 0       Paul  Deitel
# 1     Harvey  Deitel
# 2      Abbey  Deitel
# 3        Dan   Quirk
# 4  Alexander    Wald

# %%
pd.read_sql("""SELECT first, last
           FROM authors
           ORDER BY first """ , connection)
# Out:
#        first    last
# 0      Abbey  Deitel
# 1  Alexander    Wald
# 2        Dan   Quirk
# 3     Harvey  Deitel
# 4       Paul  Deitel

# %%
pd.read_sql("""SELECT first, last
           FROM authors
           ORDER BY first ASC""" , connection)
# Out:
#        first    last
# 0      Abbey  Deitel
# 1  Alexander    Wald
# 2        Dan   Quirk
# 3     Harvey  Deitel
# 4       Paul  Deitel

# %%
# Module 6 Assignment Ramon Torres SEPT 23 2022
